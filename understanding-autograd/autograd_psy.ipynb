# %% [markdown]
# # Testing out Autograd in PyTorch

# %%
import torch

# %%
a = torch.tensor(3.0, requires_grad=True)
b = torch.tensor(4.0, requires_grad=True)

c = a * b
d = c + a
e = d**2

# %%
print(a.grad_fn)
# Out:
# None

# %%
e.backward()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 e.backward()
#
# File ~/miniconda3/envs/learnml/lib/python3.12/site-packages/torch/_tensor.py:630, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     620 if has_torch_function_unary(self):
#     621     return handle_torch_function(
#     622         Tensor.backward,
#     623         (self,),
#    (...)    628         inputs=inputs,
#     629     )
# --> 630 torch.autograd.backward(
#     631     self, gradient, retain_graph, create_graph, inputs=inputs
#     632 )
#
# File ~/miniconda3/envs/learnml/lib/python3.12/site-packages/torch/autograd/__init__.py:357, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     354     tensors = tuple(tensors)
#     356 grad_tensors_ = _tensor_or_tensors_to_tuple(grad_tensors, len(tensors))
# ...
